# %%
from graph_loader import *
from spectral import *

# %%
p = 0.1
B = sp.csr_matrix(np.random.choice([0,1], size=(50,70), p=[1-p,p]))
G = matrix_to_graph(B)
A = adjacency(G)

# %%
U,S,Vt = np.linalg.svd(B.todense(), full_matrices=False)

# %%
spectral = spectral_matrix_full(G,A,phi,h,g)

# %%
print(spectral)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 746 stored elements and shape (120, 120)>
#   Coords	Values
#   (0, 53)	0.09123272448778152
#   (0, 55)	0.12381250411272049
#   (0, 61)	0.1446911096572876
#   (0, 66)	0.11004170775413513
#   (0, 68)	0.12157419323921204
#   (0, 75)	0.10801060497760773
#   (0, 94)	0.09909519553184509
#   (1, 57)	0.09145491570234299
#   (1, 58)	0.10383309423923492
#   (1, 65)	0.0715843215584755
#   (1, 66)	0.09311150014400482
#   (1, 72)	0.1500685065984726
#   (1, 93)	0.05972251668572426
#   (1, 98)	0.06019705533981323
#   (1, 100)	0.07056991755962372
#   (1, 116)	0.07676760852336884
#   (1, 118)	0.06268354505300522
#   (2, 62)	0.09122095257043839
#   (2, 63)	0.11157960444688797
#   (2, 65)	0.08683902025222778
#   (2, 77)	0.08204378932714462
#   (2, 93)	0.07631480693817139
#   (2, 114)	0.12564581632614136
#   (2, 118)	0.0777248740196228
#   (3, 51)	0.09274888783693314
#   :	:
#   (116, 8)	0.07225066423416138
#   (116, 10)	0.09104251116514206
#   (116, 12)	0.1250147670507431
#   (116, 28)	0.06862575560808182
#   (116, 45)	0.09937883913516998
#   (116, 49)	0.09195739775896072
#   (117, 6)	0.09342637658119202
#   (117, 8)	0.0749087929725647
#   (117, 14)	0.08406011015176773
#   (117, 26)	0.09860231727361679
#   (117, 38)	0.09126865118741989
#   (117, 47)	0.13575537502765656
#   (118, 1)	0.06268354505300522
#   (118, 2)	0.0777248740196228
#   (118, 8)	0.06093265861272812
#   (118, 13)	0.07171168923377991
#   (118, 21)	0.06314948946237564
#   (118, 28)	0.0556827038526535
#   (118, 36)	0.06506917625665665
#   (118, 40)	0.07449927181005478
#   (118, 41)	0.06872035562992096
#   (118, 43)	0.05875121429562569
#   (119, 3)	0.11227607727050781
#   (119, 14)	0.12751153111457825
#   (119, 36)	0.12316989153623581
